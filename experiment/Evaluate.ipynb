# %%
import pickle
from warnings import filterwarnings
filterwarnings("ignore")

import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="talk")

from jcopml.plot import plot_classification_report

# %% [markdown]
# ## Load Model

# %%
model = pickle.load(open("model_xgb.pkl", 'rb'))

# %% [markdown]
# ## Load Data test

# %%
df_test = (pd.read_csv("../dataset/test.csv").drop(columns="id"))
df = df_test.copy()

# %%
pd.DataFrame(model.predict_proba(df_test))
# Out:
#             0         1         2         3
# 0    0.071940  0.073261  0.274868  0.579931
# 1    0.062869  0.082683  0.292623  0.561825
# 2    0.099078  0.173513  0.395339  0.332070
# 3    0.028438  0.029722  0.074765  0.867075
# 4    0.144137  0.373365  0.411305  0.071192
# ..        ...       ...       ...       ...
# 995  0.060080  0.301478  0.569836  0.068605
# 996  0.124444  0.502989  0.290526  0.082041
# 997  0.435649  0.390588  0.108654  0.065109
# 998  0.078869  0.130349  0.577203  0.213578
# 999  0.049135  0.070190  0.665217  0.215458
#
# [1000 rows x 4 columns]

# %%
df["hasil_prediksi"] = model.predict(df_test)
df = pd.concat([df, pd.DataFrame(model.predict_proba(df_test)).add_prefix("proba_")], axis="columns")

# %%
df
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
#df.to_feather("hasil_prediksi.feather")
